# %% [markdown]
# # Initialization and Configuration

# %%
master_ip = "192.168.0.100"

deploy_list = [
    "redis-cart",
    "shippingservice",
    "paymentservice",
    "productcatalogservice",
    "emailservice",
    "checkoutservice",
    "recommendationservice",
    "currencyservice",
    "cartservice",
    "adservice",
    "loadgenerator",
    "frontend",
]

# %% [markdown]
# # Kubernetes API

# %%
from kubernetes import client, config
config.load_kube_config()

api_instance = client.AppsV1Api()

def get_replica_and_ready(deployment_name, deployment_ns="default"):
    api_response = api_instance.read_namespaced_deployment(deployment_name, deployment_ns)
    return api_response.status.replicas, api_response.status.ready_replicas

def set_replica_num(rnum, deployment_name, deployment_ns="default"):
    rnum = int(rnum)
    if rnum < 1:
        rnum = 1
    api_response = api_instance.read_namespaced_deployment(deployment_name, deployment_ns)
    api_response.spec.replicas = rnum
    api_instance.patch_namespaced_deployment_scale(deployment_name, deployment_ns, api_response)

# %%
get_replica_and_ready('frontend')
# Out:
# (1, 1)

# %%
# set_replica_num(1,'frontend')

# %% [markdown]
# # Locust API

# %%
import pacs_load_tester as load_tester

locust_base = f"http://{master_ip}:8089/"

# %%
# get current status
load_tester.get_current_stats(base=locust_base)
# Out:
# {'current_max_response_time': None,
#  'current_min_response_time': None,
#  'current_response_time_average': None,
#  'current_response_time_percentile_50': None,
#  'current_response_time_percentile_95': None,
#  'errors': [],
#  'fail_ratio': 0.0,
#  'state': 'stopped',
#  'stats': [{'avg_content_length': 10917.333333333334,
#    'avg_response_time': 349.04674941867404,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 6.0,
#    'max_response_time': 585.0,
#    'median_response_time': 400.0,
#    'method': 'GET',
#    'min_response_time': 10.0,
#    'name': '/',
#    'ninetieth_response_time': 560.0,
#    'num_failures': 0,
#    'num_requests': 117,
#    'safe_name': '/'},
#   {'avg_content_length': 7503.339285714285,
#    'avg_response_time': 82.25987910632934,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 3.4,
#    'max_response_time': 303.0,
#    'median_response_time': 11,
#    'method': 'GET',
#    'min_response_time': 8.0,
#    'name': '/cart',
#    'ninetieth_response_time': 290.0,
#    'num_failures': 0,
#    'num_requests': 56,
#    'safe_name': '/cart'},
#   {'avg_content_length': 15735.204545454546,
#    'avg_response_time': 109.9380174544587,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 2.4,
#    'max_response_time': 478.0,
#    'median_response_time': 17,
#    'method': 'POST',
#    'min_response_time': 12.0,
#    'name': '/cart',
#    'ninetieth_response_time': 310.0,
#    'num_failures': 0,
#    'num_requests': 44,
#    'safe_name': '/cart'},
#   {'avg_content_length': 6614.583333333333,
#    'avg_response_time': 68.24225424861652,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 0.7,
#    'max_response_time': 209.0,
#    'median_response_time': 42,
#    'method': 'POST',
#    'min_response_time': 24.0,
#    'name': '/cart/checkout',
#    'ninetieth_response_time': 110.0,
#    'num_failures': 0,
#    'num_requests': 12,
#    'safe_name': '/cart/checkout'},
#   {'avg_content_length': 8197.444444444445,
#    'avg_response_time': 110.87073144234536,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 1.2,
#    'max_response_time': 374.0,
#    'median_response_time': 12,
#    'method': 'GET',
#    'min_response_time': 8.0,
#    'name': '/product/0PUK6V6EV0',
#    'ninetieth_response_time': 310.0,
#    'num_failures': 0,
#    'num_requests': 18,
#    'safe_name': '/product/0PUK6V6EV0'},
#   {'avg_content_length': 8271.068965517241,
#    'avg_response_time': 113.40839703314424,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 1.5,
#    'max_response_time': 385.0,
#    'median_response_time': 13,
#    'method': 'GET',
#    'min_response_time': 9.0,
#    'name': '/product/1YMWWN1N4O',
#    'ninetieth_response_time': 320.0,
#    'num_failures': 0,
#    'num_requests': 29,
#    'safe_name': '/product/1YMWWN1N4O'},
#   {'avg_content_length': 8250.25,
#    'avg_response_time': 105.47128960097325,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 1.2,
#    'max_response_time': 381.0,
#    'median_response_time': 13,
#    'method': 'GET',
#    'min_response_time': 10.0,
#    'name': '/product/2ZYFJ3GM2N',
#    'ninetieth_response_time': 330.0,
#    'num_failures': 0,
#    'num_requests': 20,
#    'safe_name': '/product/2ZYFJ3GM2N'},
#   {'avg_content_length': 8262.5,
#    'avg_response_time': 115.79372929918463,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 0.9,
#    'max_response_time': 317.0,
#    'median_response_time': 16,
#    'method': 'GET',
#    'min_response_time': 9.0,
#    'name': '/product/66VCHSJNUP',
#    'ninetieth_response_time': 310.0,
#    'num_failures': 0,
#    'num_requests': 20,
#    'safe_name': '/product/66VCHSJNUP'},
#   {'avg_content_length': 8267.708333333334,
#    'avg_response_time': 79.10530704187597,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 1.2,
#    'max_response_time': 308.0,
#    'median_response_time': 13,
#    'method': 'GET',
#    'min_response_time': 10.0,
#    'name': '/product/6E92ZMYYFZ',
#    'ninetieth_response_time': 290.0,
#    'num_failures': 0,
#    'num_requests': 24,
#    'safe_name': '/product/6E92ZMYYFZ'},
#   {'avg_content_length': 8228.407407407407,
#    'avg_response_time': 133.76190225891253,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 1.5,
#    'max_response_time': 393.0,
#    'median_response_time': 13,
#    'method': 'GET',
#    'min_response_time': 8.0,
#    'name': '/product/9SIQT8TOJO',
#    'ninetieth_response_time': 320.0,
#    'num_failures': 0,
#    'num_requests': 27,
#    'safe_name': '/product/9SIQT8TOJO'},
#   {'avg_content_length': 8260.3125,
#    'avg_response_time': 83.64659553080855,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 1.4,
#    'max_response_time': 380.0,
#    'median_response_time': 11,
#    'method': 'GET',
#    'min_response_time': 9.0,
#    'name': '/product/L9ECAV7KIM',
#    'ninetieth_response_time': 300.0,
#    'num_failures': 0,
#    'num_requests': 32,
#    'safe_name': '/product/L9ECAV7KIM'},
#   {'avg_content_length': 8296.56,
#    'avg_response_time': 144.5881029998418,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 1.2,
#    'max_response_time': 391.0,
#    'median_response_time': 130.0,
#    'method': 'GET',
#    'min_response_time': 8.0,
#    'name': '/product/LS4PSXUNUM',
#    'ninetieth_response_time': 310.0,
#    'num_failures': 0,
#    'num_requests': 25,
#    'safe_name': '/product/LS4PSXUNUM'},
#   {'avg_content_length': 8219.4,
#    'avg_response_time': 95.35161235180567,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 1.0,
#    'max_response_time': 373.0,
#    'median_response_time': 11,
#    'method': 'GET',
#    'min_response_time': 8.0,
#    'name': '/product/OLJCESPC7Z',
#    'ninetieth_response_time': 370.0,
#    'num_failures': 0,
#    'num_requests': 20,
#    'safe_name': '/product/OLJCESPC7Z'},
#   {'avg_content_length': 10929.512195121952,
#    'avg_response_time': 80.12194002491547,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 2.2,
#    'max_response_time': 411.0,
#    'median_response_time': 16,
#    'method': 'POST',
#    'min_response_time': 11.0,
#    'name': '/setCurrency',
#    'ninetieth_response_time': 310.0,
#    'num_failures': 0,
#    'num_requests': 41,
#    'safe_name': '/setCurrency'},
#   {'avg_content_length': 9673.696907216496,
#    'avg_response_time': 160.42174008016633,
#    'current_fail_per_sec': 0.0,
#    'current_rps': 25.8,
#    'max_response_time': 585.0,
#    'median_response_time': 29,
#    'method': None,
#    'min_response_time': 8.0,
#    'name': 'Aggregated',
#    'ninetieth_response_time': 420.0,
#    'num_failures': 0,
#    'num_requests': 485,
#    'safe_name': 'Aggregated'}],
#  'total_average_response_time': 160.42174008016633,
#  'total_rps': 25.8,
#  'user_count': 0}

# %% [markdown]
# # Running A Sequence

# %%
import pandas as pd
from tqdm.auto import tqdm
import time
tqdm.pandas()

loop_timer = load_tester.TimerClass()
total_timer = load_tester.TimerClass()

# user_sequence = [50,100,500,1000,1000,1000,500,100,50]
user_sequence = [50,100]
lt = load_tester.PACSLoadTester(hatch_rate=1000, temp_stat_max_len=5, base=locust_base)
lt.change_count(user_sequence[0])
# wait for changes to take effect
time.sleep(2)
lt.start_capturing()

loop_time_in_secs = load_tester.get_loop_time_in_secs('10s')

loop_timer.tic()
total_timer.tic()

arr_results = []
for i in tqdm(range(len(user_sequence))):
    user_count = user_sequence[i]
    lt.change_count(user_count)
    
    time.sleep(loop_time_in_secs - loop_timer.toc())
    
    loop_timer.tic()
    
    result = lt.get_all_stats()    
    arr_results.append(result)
    
lt.stop_test()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2.0), HTML(value='')))
# True

# %%
results = None
for result in arr_results:
    df_result = pd.DataFrame(data=result)
    
    if results is None:
        results = df_result
    else:
        results = results.append(df_result)

results, filename = lt.prepare_results_from_df(results)

# %%
results.head()
# Out:
#            time  current_response_time_percentile_50  \
# 0  1.610844e+09                                300.0
# 1  1.610844e+09                                290.0
# 2  1.610844e+09                                210.0
# 3  1.610844e+09                                210.0
# 4  1.610844e+09                                190.0
#
#    current_response_time_percentile_95  current_response_time_average  \
# 0                                500.0                            304
# 1                                500.0                            263
# 2                                500.0                            230
# 3                                500.0                            230
# 4                                490.0                            197
#
#    current_max_response_time  current_min_response_time  fail_ratio  \
# 0                        570                         10         0.0
# 1                        570                          8         0.0
# 2                        570                          8         0.0
# 3                        570                          8         0.0
# 4                        570                          8         0.0
#
#    total_rps  user_count  avg_response_time  current_rps  max_response_time  \
# 0       0.00          50         391.851575     0.000000              568.0
# 1      56.50          50         391.851575    26.000000              568.0
# 2      31.75          50         371.420011    13.000000              568.0
# 3      31.75          50         371.420011    13.000000              568.0
# 4      22.00          50         364.950288     7.857143              568.0
#
#    median_response_time  min_response_time  num_failures  num_requests  \
# 0                 410.0              104.0             0            52
# 1                 410.0              104.0             0            52
# 2                 410.0                9.0             0            55
# 3                 410.0                9.0             0            55
# 4                 410.0                9.0             0            56
#
#     elapsed  elapsed_min
# 0  0.000000     0.000000
# 1  2.002223     0.033370
# 2  4.004701     0.066745
# 3  6.003885     0.100065
# 4  8.004728     0.133412

# %% [markdown]
# # Plotting The Results

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

res = results

plt.figure(figsize=(8,18))
plt.subplot(411)
plt.plot(res['elapsed_min'], res['current_min_response_time'], label='current_min_response_time')
plt.plot(res['elapsed_min'], res['current_response_time_percentile_50'], label='median_response_time')
plt.plot(res['elapsed_min'], res['current_response_time_average'], label='avg_response_time')
plt.plot(res['elapsed_min'], res['current_response_time_percentile_95'], label='95th percentile')
plt.plot(res['elapsed_min'], res['current_max_response_time'], label='current_max_response_time')

plt.xlabel('Time (minutes)')
plt.ylabel('Average Response Time (ms)')
plt.legend()

plt.subplot(412)
plt.plot(res['elapsed_min'], res['user_count'])
plt.xlabel('Time (minutes)')
plt.ylabel('Num of Users')

plt.subplot(413)
plt.plot(res['elapsed_min'], res['total_rps'])
plt.xlabel('Time (minutes)')
plt.ylabel('Throughput (req/s)')

plt.subplot(414)
plt.plot(res['elapsed_min'], res['fail_ratio'])
plt.xlabel('Time (minutes)')
plt.ylabel('Fail Ratio')

filename = filename.replace('.csv', '')
plt.savefig(filename + '.png', dpi=300)
plt.savefig(filename + '.pdf')
plt.show()

# %% [markdown]
# # Pormetheus API

# %%
prometheus_base = f"http://{master_ip}:9090"
prometheus_base
# Out:
# 'http://192.168.23.88:9090'

# %%
from prometheus_api_client import PrometheusConnect
prom = PrometheusConnect(url=prometheus_base, disable_ssl=True)

# Get the list of all the metrics that the Prometheus host scrapes
# (only top 10 is shown)
prom.all_metrics()[:10]
# Out:
# [':kube_pod_info_node_count:',
#  ':node_memory_MemAvailable_bytes:sum',
#  'ALERTS',
#  'ALERTS_FOR_STATE',
#  'aggregator_openapi_v2_regeneration_count',
#  'aggregator_openapi_v2_regeneration_duration',
#  'aggregator_unavailable_apiservice',
#  'alertmanager_alerts',
#  'alertmanager_alerts_invalid_total',
#  'alertmanager_alerts_received_total']

# %%
# get pod count
query_pod_count = """count(
        kube_pod_info{namespace="default"}
    ) by (created_by_kind,created_by_name)"""
get_pod_count_query = lambda: prom.custom_query(query=query_pod_count)

count_q_res = get_pod_count_query()
count_q_res[0]
# Out:
# {'metric': {'created_by_kind': 'DaemonSet',
#   'created_by_name': 'svclb-frontend-external'},
#  'value': [1610844302.641, '2']}

# %%
def get_pod_count(deploy_name, query_res):
    filtered_res = [{
        'name': q['metric']['created_by_name'],
        'count': int(q['value'][1]),
    } for q in count_q_res]
    for res in filtered_res:
        if res['name'].startswith(deploy_name):
            return res['count']
    # if not found, return -1
    return -1

get_pod_count('frontend', count_q_res)
# Out:
# 1

# %%
deploy_pod_counts = {}
for d in deploy_list:
    deploy_pod_counts[d] = get_pod_count(d, count_q_res)
deploy_pod_counts
# Out:
# {'redis-cart': 1,
#  'shippingservice': 1,
#  'paymentservice': 1,
#  'productcatalogservice': 1,
#  'emailservice': 1,
#  'checkoutservice': 1,
#  'recommendationservice': 1,
#  'currencyservice': 1,
#  'cartservice': 1,
#  'adservice': 1,
#  'loadgenerator': 1,
#  'frontend': 1}

# %%
# get workload cpu
query_workload_cpu = """
sum(
  rate(container_cpu_usage_seconds_total{cluster="", namespace="default"}[2m])
* on(namespace,pod)
  group_left(workload, workload_type) namespace_workload_pod:kube_pod_owner:relabel{cluster="", namespace="default", workload_type="deployment"}
) by (workload, workload_type)
"""
get_workload_cpu_query = lambda: prom.custom_query(query=query_workload_cpu)

wl_cpu_res = get_workload_cpu_query()
wl_cpu_res[0]
# Out:
# {'metric': {'workload': 'emailservice', 'workload_type': 'deployment'},
#  'value': [1610844304.573, '0.005017956942778258']}

# %%
# filter results (unit is millicores)
filtered_cpu_query = { q['metric']['workload']: float(q['value'][1])*1000 for q in wl_cpu_res }
filtered_cpu_query
# Out:
# {'emailservice': 5.017956942778258,
#  'shippingservice': 4.109814280540783,
#  'cartservice': 6.297491712560369,
#  'paymentservice': 2.5204650182161386,
#  'frontend': 9.51284468287259,
#  'productcatalogservice': 2.250330067563266,
#  'checkoutservice': 4.575033024047848,
#  'adservice': 11.257179402287719,
#  'currencyservice': 8.839029328085152,
#  'redis-cart': 0.8577635425493534,
#  'loadgenerator': 0.7554945029643577,
#  'recommendationservice': 9.66668666129519}
